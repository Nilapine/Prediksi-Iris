# %%
import pandas as pd

# %%
pd.show_versions (as_json=False)
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : bdc79c146c2e32f2cab629be240f01658cfb6cc2
# python                : 3.12.2.final.0
# python-bits           : 64
# OS                    : Windows
# OS-release            : 10
# Version               : 10.0.19045
# machine               : AMD64
# processor             : Intel64 Family 6 Model 60 Stepping 3, GenuineIntel
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : English_Indonesia.1252
#
# pandas                : 2.2.1
# numpy                 : 1.26.4
# pytz                  : 2024.1
# dateutil              : 2.9.0.post0
# setuptools            : 70.1.1
# pip                   : 24.3.1
# Cython                : None
# pytest                : 8.2.2
# hypothesis            : None
# sphinx                : None
# blosc                 : None
# feather               : None
# xlsxwriter            : None
# lxml.etree            : None
# html5lib              : None
# pymysql               : None
# psycopg2              : None
# jinja2                : 3.1.3
# IPython               : 8.22.2
# pandas_datareader     : None
# adbc-driver-postgresql: None
# adbc-driver-sqlite    : None
# bs4                   : 4.12.3
# bottleneck            : None
# dataframe-api-compat  : None
# fastparquet           : None
# fsspec                : 2024.10.0
# gcsfs                 : None
# matplotlib            : 3.8.3
# numba                 : None
# numexpr               : None
# odfpy                 : None
# openpyxl              : 3.1.5
# pandas_gbq            : None
# pyarrow               : 18.1.0
# pyreadstat            : None
# python-calamine       : None
# pyxlsb                : None
# s3fs                  : None
# scipy                 : 1.12.0
# sqlalchemy            : None
# tables                : None
# tabulate              : None
# xarray                : None
# xlrd                  : None
# zstandard             : None
# tzdata                : 2024.1
# qtpy                  : None
# pyqt5                 : None

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Ganti dengan path gambar yang ingin ditampilkan
img = mpimg.imread('media/virginica.jpg')

# Menampilkan gambar
plt.imshow(img)
plt.axis('off')  # Menonaktifkan sumbu
plt.title('Iris Virginica')
plt.show()

# %%
# !pip install streamlit-option-menu
# Out:
# Requirement already satisfied: streamlit-option-menu in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (0.4.0)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\Nila Farihah\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\Nila Farihah\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\Nila Farihah\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# Requirement already satisfied: streamlit>=1.36 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit-option-menu) (1.41.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (24.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (2.2.1)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (10.2.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (13.7.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (6.4)
# Requirement already satisfied: jinja2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (4.21.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (1.15.2)
# Requirement already satisfied: colorama in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from click<9,>=7.0->streamlit>=1.36->streamlit-option-menu) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit-option-menu) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit-option-menu) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\nila farihah\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.36->streamlit-option-menu) (1.16.0)

# %%
pip show streamlit-option-menu
# Out:
# Name: streamlit-option-menu
# Version: 0.4.0
# Summary: streamlit-option-menu is a simple Streamlit component that allows users to select a single item from a list of options in a menu.
# Home-page: https://github.com/victoryhb/streamlit-option-menu
# Author: Victor Yan
# Author-email: victoryhb@163.com
# License: UNKNOWN
# Location: C:\Users\Nila Farihah\AppData\Local\Programs\Python\Python312\Lib\site-packages
# Requires: streamlit
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\Nila Farihah\AppData\Local\Programs\Python\Python312\Lib\site-packages)
